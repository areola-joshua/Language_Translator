# %%
import subprocess

# Run the Streamlit app in the background
subprocess.Popen(["streamlit", "run", "Translate.py", "--server.port=8501"])
# Out:
# <Popen: returncode: None args: ['streamlit', 'run', 'Translate.py', '--serve...>
